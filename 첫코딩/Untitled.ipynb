# %%
import pandas as pd

exercise = pd.read_excel("./data/seoul_exercise.xlsx")
exercise
# Out:
#       시점  구분별(1)        구분별(2)                 합계              합계.1  \
# 0     시점  구분별(1)        구분별(2)  운동을 할 충분한 시간이 없어서  함께 운동을 할 사람이 없어서
# 1   2019     서울시            소계               46.8               5.0
# 2    NaN      성별            남자               52.4               4.4
# 3    NaN     NaN            여자               42.5               5.6
# 4    NaN     연령별           10대               55.3               4.8
# 5    NaN     NaN           20대               46.0               4.2
# 6    NaN     NaN           30대               59.9               5.2
# 7    NaN     NaN           40대               54.1               3.9
# 8    NaN     NaN           50대               46.1               6.2
# 9    NaN     NaN        60대 이상               26.6               6.0
# 10   NaN     학력별         중졸 이하               24.7               6.2
# 11   NaN     NaN         고졸 이하               44.3               5.3
# 12   NaN     NaN         대졸 이하               53.1               4.7
# ...
