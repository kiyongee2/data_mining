# %%
import csv

f = open('Data/age_2023.csv')
data = csv.reader(f)
for row in data:
    if '신도림' in row[0]:
        print(row)
f.close()
# Out:
# ['서울특별시 구로구 신도림동(1153051000)', '35,812', '35,812', '3,166', '3,554', '4,189', '5,868', '6,483', '5,206', '4,252', '2,179', '807', '106', '2']

# %%
with open('Data/age_2023.csv') as f:
    data = csv.reader(f)
    for row in data:
        if '신도림' in row[0]:
            print(row)
# Out:
# ['서울특별시 구로구 신도림동(1153051000)', '35,812', '35,812', '3,166', '3,554', '4,189', '5,868', '6,483', '5,206', '4,252', '2,179', '807', '106', '2']

# %%
# 연령별 인구수 시각화
import matplotlib.pyplot as plt

f = open('Data/age_2023.csv')
data = csv.reader(f)
result = []   # 연령별 인구 저장 리스트

for row in data:
    if '평택시' in row[0]:
        for i in row[3:]:
            result.append(int(i.replace(',', '')))  # 정수로 변환
        break
            
#print("0~100세 개수 :", len(row[3:]))
print(result)
plt.style.use("ggplot")  # 격자 무늬 스타일 지정
plt.plot(result)
plt.show()
# Out:
# [49095, 55611, 77753, 89493, 100247, 94590, 65192, 29676, 16131, 2168, 55]

# %%
# 지역을 입력받아 꺽은선 그래프 그리기

f = open('Data/age_2023.csv')
data = csv.reader(f)
result = []   # 연령별 인구 저장 리스트
name = input("인구 구조가 알고 싶은 지역의 이름(읍면동 단위)을 입력해 주세요:")

for row in data:
    if name in row[0]:
        for i in row[3:]:
            result.append(int(i.replace(',', '')))  # 정수로 변환, 콤머 제거   
        break
            
plt.title(name + " 지역의 인구 구조")
plt.rc('font', family='Malgun Gothic')
plt.style.use("ggplot")  # 격자 무늬 스타일 지정
plt.plot(result)
plt.show()
# Out:
# 인구 구조가 알고 싶은 지역의 이름(읍면동 단위)을 입력해 주세요:수원시

# %%
# 막대 그래프 그리기

f = open('Data/age.csv')
data = csv.reader(f)
result = []   # 연령별 인구 저장 리스트
name = input("인구 구조가 알고 싶은 지역의 이름(읍면동 단위)을 입력해 주세요:")

for row in data:
    if name in row[0]:
        for i in row[3:]:
            result.append(int(i))  # 정수로 변환   
            
plt.title(name + " 지역의 인구 구조")
plt.rc('font', family='Malgun Gothic')
plt.bar(range(101), result)
plt.show()
# Out:
# 인구 구조가 알고 싶은 지역의 이름(읍면동 단위)을 입력해 주세요:포승읍
